# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Lab6
#
# # 目標：groupby、corr、plt

# %% [markdown]
# # 預處理
#
# ## 請參考lab5爬取資料
#
# ### 請把date的資料型態更改為datetime，closing_price資料型態更改為float64

# %%
#參考lab5
data = pd.read_csv('./data_science_data.csv',index_col=0)
#提取資料
data = data[['date','證券名稱','收盤價']]
#更改名字
data = data.rename(columns = {'證券名稱':'name'})
data = data.rename(columns = {'收盤價':'closing_price'})
#清理資料
data['closing_price'] = data['closing_price'].replace({'\$':'', ',':'', '--':np.nan}, regex=True)
data = data.dropna()
#更改資料型態
data['closing_price'] = data['closing_price'].astype('float64')
data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261818 entries, 0 to 1113
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           261818 non-null  datetime64[ns]
#  1   name           261818 non-null  object
#  2   closing_price  261818 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 8.0+ MB

# %% [markdown]
# ## pd.groupby
#
# 對數據進行分組計算

# %%
#data_group = data.groupby('name')
# Out:
#           date name  closing_price
# 602 2019-01-02  富邦金          46.10
# 602 2019-01-03  富邦金          45.80
# 602 2019-01-04  富邦金          45.30
# 602 2019-01-07  富邦金          45.95
# 602 2019-01-08  富邦金          45.70
# ..         ...  ...            ...
# 625 2019-12-25  富邦金          46.45
# 625 2019-12-26  富邦金          46.50
# 625 2019-12-27  富邦金          46.75
# 624 2019-12-30  富邦金          46.70
# 624 2019-12-31  富邦金          46.40
#
# [242 rows x 3 columns]

# %% [markdown]
# ### get_group 提取資料

# %%
data_group.get_group('富邦金')
# Out:
#           date name  closing_price
# 602 2019-01-02  富邦金          46.10
# 602 2019-01-03  富邦金          45.80
# 602 2019-01-04  富邦金          45.30
# 602 2019-01-07  富邦金          45.95
# 602 2019-01-08  富邦金          45.70
# ..         ...  ...            ...
# 625 2019-12-25  富邦金          46.45
# 625 2019-12-26  富邦金          46.50
# 625 2019-12-27  富邦金          46.75
# 624 2019-12-30  富邦金          46.70
# 624 2019-12-31  富邦金          46.40
#
# [242 rows x 3 columns]

# %%
for (name, group) in data_group:
    print(name)
    print(group)
# Out:
# BP上證50
#           date    name  closing_price
# 114 2019-01-02  BP上證50          84.55
# 114 2019-01-03  BP上證50          83.65
# 114 2019-01-04  BP上證50          85.30
# 114 2019-01-07  BP上證50          85.35
# 114 2019-01-08  BP上證50          85.25
# ..         ...     ...            ...
# 120 2019-12-25  BP上證50         106.40
# 120 2019-12-26  BP上證50         106.40
# 120 2019-12-27  BP上證50         107.10
# 119 2019-12-30  BP上證50         109.00
# 119 2019-12-31  BP上證50         109.00
#
# [230 rows x 3 columns]
# FH富時不動產
#          date     name  closing_price
# 91 2019-01-02  FH富時不動產          17.22
# 91 2019-01-03  FH富時不動產          17.05
# 91 2019-01-04  FH富時不動產          17.27
# 91 2019-01-07  FH富時不動產          17.45
# 91 2019-01-08  FH富時不動產          17.56
# ..        ...      ...            ...
# 89 2019-12-25  FH富時不動產          18.41
# 89 2019-12-26  FH富時不動產          18.34
# 89 2019-12-27  FH富時不動產          18.43
# 88 2019-12-30  FH富時不動產          18.41
# 88 2019-12-31  FH富時不動產          18.18
#
# [242 rows x 3 columns]
# FH富時高息低波
#           date      name  closing_price
# 100 2019-01-02  FH富時高息低波          46.07
# 100 2019-01-03  FH富時高息低波          45.63
# 100 2019-01-04  FH富時高息低波          45.50
# 100 2019-01-07  FH富時高息低波          46.39
# 100 2019-01-08  FH富時高息低波          46.45
# ..         ...       ...            ...
# 96  2019-12-25  FH富時高息低波          48.79
# 96  2019-12-26  FH富時高息低波          48.73
# 96  2019-12-27  FH富時高息低波          48.88
# 95  2019-12-30  FH富時高息低波          48.85
# 95  2019-12-31  FH富時高息低波          48.67
#
# [221 rows x 3 columns]
# FH彭博新興債
#          date     name  closing_price
# 90 2019-01-02  FH彭博新興債          18.84
# 90 2019-01-03  FH彭博新興債          18.96
# 90 2019-01-04  FH彭博新興債          19.12
# 90 2019-01-07  FH彭博新興債          19.20
# 90 2019-01-08  FH彭博新興債          19.27
# ..        ...      ...            ...
# 88 2019-12-25  FH彭博新興債          22.12
# 88 2019-12-26  FH彭博新興債          22.15
# 88 2019-12-27  FH彭博新興債          22.09
# 87 2019-12-30  FH彭博新興債          22.11
# 87 2019-12-31  FH彭博新興債          22.05
#
# [242 rows x 3 columns]
# FH彭博高收益債
#          date      name  closing_price
# 89 2019-01-02  FH彭博高收益債          19.63
# 89 2019-01-03  FH彭博高收益債          19.81
# 89 2019-01-04  FH彭博高收益債          19.81
# 89 2019-01-07  FH彭博高收益債          20.04
# 89 2019-01-08  FH彭博高收益債          20.14
# ..        ...       ...            ...
# 87 2019-12-25  FH彭博高收益債          20.34
# 87 2019-12-26  FH彭博高收益債          20.30
# 87 2019-12-27  FH彭博高收益債          20.29
# 86 2019-12-30  FH彭博高收益債          20.25
# 86 2019-12-31  FH彭博高收益債          20.22
#
# [242 rows x 3 columns]
# FH滬深
#          date  name  closing_price
# 15 2019-01-02  FH滬深          18.07
# 15 2019-01-03  FH滬深          18.14
# 15 2019-01-04  FH滬深          18.50
# 15 2019-01-07  FH滬深          18.65
# 15 2019-01-08  FH滬深          18.65
# ..        ...   ...            ...
# 13 2019-12-25  FH滬深          23.79
# 13 2019-12-26  FH滬深          23.85
# 13 2019-12-27  FH滬深          24.04
# 13 2019-12-30  FH滬深          24.23
# 13 2019-12-31  FH滬深          24.24
#
# [242 rows x 3 columns]
# FH美國金融股
#           date     name  closing_price
# 116 2019-01-28  FH美國金融股          20.14
# 116 2019-01-29  FH美國金融股          20.10
# 116 2019-01-30  FH美國金融股          20.00
# 116 2019-02-11  FH美國金融股          20.09
# 116 2019-02-12  FH美國金融股          20.03
# ..         ...      ...            ...
# 112 2019-12-25  FH美國金融股          23.71
# 112 2019-12-26  FH美國金融股          23.71
# 112 2019-12-27  FH美國金融股          23.84
# 111 2019-12-30  FH美國金融股          23.80
# 111 2019-12-31  FH美國金融股          23.58
#
# [224 rows x 3 columns]
# FH香港
#          date  name  closing_price
# 37 2019-01-02  FH香港          18.79
# 37 2019-01-03  FH香港          18.73
# 37 2019-01-04  FH香港          19.08
# 37 2019-01-07  FH香港          19.34
# 37 2019-01-08  FH香港          19.36
# ..        ...   ...            ...
# 35 2019-12-23  FH香港          20.85
# 35 2019-12-24  FH香港          20.82
# 35 2019-12-25  FH香港          20.69
# 35 2019-12-26  FH香港          20.76
# 35 2019-12-27  FH香港          21.05
#
# [240 rows x 3 columns]
# FH香港反1
#          date    name  closing_price
# 39 2019-01-02  FH香港反1           9.39
# 39 2019-01-03  FH香港反1           9.48
# 39 2019-01-04  FH香港反1           9.37
# 39 2019-01-07  FH香港反1           9.19
# 39 2019-01-08  FH香港反1           9.16
# ..        ...     ...            ...
# 37 2019-12-25  FH香港反1           8.02
# 37 2019-12-26  FH香港反1           8.00
# 37 2019-12-27  FH香港反1           7.96
# 36 2019-12-30  FH香港反1           7.93
# 36 2019-12-31  FH香港反1           7.99
#
# [242 rows x 3 columns]
# FH香港正2
#          date    name  closing_price
# 38 2019-01-02  FH香港正2          24.83
# 38 2019-01-03  FH香港正2          24.40
# 38 2019-01-04  FH香港正2          25.27
# 38 2019-01-07  FH香港正2          26.21
# 38 2019-01-08  FH香港正2          26.19
# ..        ...     ...            ...
# 36 2019-12-25  FH香港正2          30.03
# 36 2019-12-26  FH香港正2          30.00
# 36 2019-12-27  FH香港正2          30.89
# 35 2019-12-30  FH香港正2          31.24
# 35 2019-12-31  FH香港正2          30.85
#
# [242 rows x 3 columns]
# GIS-KY
#           date    name  closing_price
# 941 2019-01-02  GIS-KY           89.3
# 941 2019-01-03  GIS-KY           86.2
# 941 2019-01-04  GIS-KY           85.6
# 941 2019-01-07  GIS-KY           94.1
# 942 2019-01-08  GIS-KY           92.5
# ..         ...     ...            ...
# 975 2019-12-25  GIS-KY          111.0
# 975 2019-12-26  GIS-KY          113.0
# 975 2019-12-27  GIS-KY          113.5
# 974 2019-12-30  GIS-KY          112.0
# 974 2019-12-31  GIS-KY          113.0
#
# [242 rows x 3 columns]
# TPK-KY
#           date    name  closing_price
# 755 2019-01-02  TPK-KY           47.5
# 755 2019-01-03  TPK-KY           46.6
# 755 2019-01-04  TPK-KY           48.5
# 755 2019-01-07  TPK-KY           50.3
# 756 2019-01-08  TPK-KY           50.6
# ..         ...     ...            ...
# 781 2019-12-25  TPK-KY           56.5
# 781 2019-12-26  TPK-KY           56.7
# 781 2019-12-27  TPK-KY           57.1
# 780 2019-12-30  TPK-KY           56.7
# 780 2019-12-31  TPK-KY           56.8
#
# [242 rows x 3 columns]
# jpp-KY
#           date    name  closing_price
# 844 2019-01-02  jpp-KY          53.40
# 844 2019-01-03  jpp-KY          53.40
# 844 2019-01-04  jpp-KY          53.40
# 844 2019-01-07  jpp-KY          53.40
# 845 2019-01-08  jpp-KY          53.30
# ..         ...     ...            ...
# 877 2019-12-25  jpp-KY          49.80
# 877 2019-12-26  jpp-KY          48.45
# 877 2019-12-27  jpp-KY          48.65
# 876 2019-12-30  jpp-KY          48.50
# 876 2019-12-31  jpp-KY          48.40
#
# [242 rows x 3 columns]
# 一詮
#           date name  closing_price
# 508 2019-01-02   一詮           9.34
# 508 2019-01-03   一詮           9.17
# 508 2019-01-04   一詮           9.08
# 508 2019-01-07   一詮           9.13
# 508 2019-01-08   一詮           9.16
# ..         ...  ...            ...
# 531 2019-12-25   一詮           9.27
# 531 2019-12-26   一詮           9.53
# 531 2019-12-27   一詮           9.29
# 530 2019-12-30   一詮           9.05
# 530 2019-12-31   一詮           9.15
#
# [242 rows x 3 columns]
# 一零四
#           date name  closing_price
# 692 2019-01-02  一零四          152.0
# 692 2019-01-03  一零四          152.0
# 692 2019-01-04  一零四          152.0
# 693 2019-01-08  一零四          152.0
# 694 2019-01-09  一零四          154.0
# ..         ...  ...            ...
# 719 2019-12-25  一零四          163.0
# 719 2019-12-26  一零四          161.0
# 719 2019-12-27  一零四          162.5
# 718 2019-12-30  一零四          161.5
# 718 2019-12-31  一零四          160.5
#
# [224 rows x 3 columns]
# 三商
#           date name  closing_price
# 624 2019-01-02   三商          17.95
# 624 2019-01-03   三商          17.70
# 624 2019-01-04   三商          17.25
# 624 2019-01-07   三商          17.35
# 625 2019-01-08   三商          17.30
# ..         ...  ...            ...
# 651 2019-12-25   三商          21.40
# 651 2019-12-26   三商          21.70
# 651 2019-12-27   三商          21.50
# 650 2019-12-30   三商          21.50
# 650 2019-12-31   三商          21.65
#
# [242 rows x 3 columns]
# 三商壽
#           date name  closing_price
# 600 2019-01-02  三商壽          11.30
# 600 2019-01-03  三商壽          11.35
# 600 2019-01-04  三商壽          11.40
# 600 2019-01-07  三商壽          11.40
# 600 2019-01-08  三商壽          11.30
# ..         ...  ...            ...
# 623 2019-12-25  三商壽          11.80
# 623 2019-12-26  三商壽          11.65
# 623 2019-12-27  三商壽          11.65
# 622 2019-12-30  三商壽          11.65
# 622 2019-12-31  三商壽          11.60
#
# [242 rows x 3 columns]
# 三商電
#           date name  closing_price
# 461 2019-01-02  三商電          11.00
# 461 2019-01-03  三商電          10.95
# 461 2019-01-04  三商電          10.85
# 461 2019-01-07  三商電          10.90
# 461 2019-01-08  三商電          11.05
# ..         ...  ...            ...
# 485 2019-12-25  三商電          10.50
# 485 2019-12-26  三商電          10.45
# 485 2019-12-27  三商電          10.55
# 484 2019-12-30  三商電          10.55
# 484 2019-12-31  三商電          10.60
#
# [242 rows x 3 columns]
# 三星
#           date name  closing_price
# 834 2019-01-02   三星           52.7
# 834 2019-01-03   三星           52.0
# 834 2019-01-04   三星           52.0
# 834 2019-01-07   三星           52.0
# 835 2019-01-08   三星           51.1
# ..         ...  ...            ...
# 867 2019-12-25   三星           51.0
# 867 2019-12-26   三星           51.0
# 867 2019-12-27   三星           51.3
# 866 2019-12-30   三星           51.9
# 866 2019-12-31   三星           57.0
#
# [242 rows x 3 columns]
# 三晃
#           date name  closing_price
# 291 2019-01-02   三晃          10.00
# 291 2019-01-03   三晃           9.85
# 291 2019-01-04   三晃           9.80
# 291 2019-01-07   三晃           9.97
# 291 2019-01-08   三晃          10.00
# ..         ...  ...            ...
# 312 2019-12-25   三晃           8.82
# 312 2019-12-26   三晃           8.81
# 312 2019-12-27   三晃           8.76
# 311 2019-12-30   三晃           8.79
# 311 2019-12-31   三晃           8.77
#
# [242 rows x 3 columns]
# 三洋紡
#           date name  closing_price
# 218 2019-01-02  三洋紡          30.90
# 218 2019-01-03  三洋紡          30.90
# 218 2019-01-04  三洋紡          30.90
# 218 2019-01-07  三洋紡          31.10
# 218 2019-01-08  三洋紡          31.00
# ..         ...  ...            ...
# 240 2019-12-25  三洋紡          27.35
# 240 2019-12-26  三洋紡          27.30
# 240 2019-12-27  三洋紡          27.25
# 239 2019-12-30  三洋紡          27.05
# 239 2019-12-31  三洋紡          27.30
#
# [242 rows x 3 columns]
# 三洋電
#           date name  closing_price
# 271 2019-01-02  三洋電          22.40
# 271 2019-01-03  三洋電          22.50
# 271 2019-01-04  三洋電          22.35
# 271 2019-01-07  三洋電          22.30
# 271 2019-01-08  三洋電          22.45
# ..         ...  ...            ...
# 293 2019-12-25  三洋電          31.30
# 293 2019-12-26  三洋電          31.15
# 293 2019-12-27  三洋電          31.30
# 292 2019-12-30  三洋電          31.30
# 292 2019-12-31  三洋電          31.30
#
# [242 rows x 3 columns]
# 三發地產
#            date  name  closing_price
# 1072 2019-01-02  三發地產          12.50
# 1072 2019-01-03  三發地產          12.50
# 1072 2019-01-04  三發地產          12.50
# 1072 2019-01-07  三發地產          12.55
# 1073 2019-01-08  三發地產          12.35
# ...         ...   ...            ...
# 1112 2019-12-25  三發地產          27.20
# 1112 2019-12-26  三發地產          26.90
# 1112 2019-12-27  三發地產          26.95
# 1111 2019-12-30  三發地產          27.25
# 1111 2019-12-31  三發地產          27.05
#
# [242 rows x 3 columns]
# 三福化
#           date name  closing_price
# 805 2019-01-02  三福化          39.25
# 805 2019-01-03  三福化          39.00
# 805 2019-01-04  三福化          38.70
# 805 2019-01-07  三福化          38.90
# 806 2019-01-08  三福化          39.10
# ..         ...  ...            ...
# 837 2019-12-25  三福化          50.50
# 837 2019-12-26  三福化          49.80
# 837 2019-12-27  三福化          49.55
# 836 2019-12-30  三福化          50.00
# 836 2019-12-31  三福化          49.90
#
# [242 rows x 3 columns]
# 三能-KY
#            date   name  closing_price
# 964  2019-01-02  三能-KY          43.85
# 964  2019-01-03  三能-KY          43.50
# 964  2019-01-04  三能-KY          42.95
# 964  2019-01-07  三能-KY          43.20
# 965  2019-01-08  三能-KY          43.20
# ...         ...    ...            ...
# 1001 2019-12-25  三能-KY          37.00
# 1001 2019-12-26  三能-KY          37.15
# 1001 2019-12-27  三能-KY          36.75
# 1000 2019-12-30  三能-KY          37.00
# 1000 2019-12-31  三能-KY          36.60
#
# [240 rows x 3 columns]
# 三芳
#           date name  closing_price
# 154 2019-01-02   三芳          24.40
# 154 2019-01-03   三芳          23.95
# 154 2019-01-04   三芳          23.30
# 154 2019-01-07   三芳          24.00
# 154 2019-01-08   三芳          23.70
# ..         ...  ...            ...
# 176 2019-12-25   三芳          23.65
# 176 2019-12-26   三芳          23.60
# 176 2019-12-27   三芳          23.65
# 175 2019-12-30   三芳          23.65
# 175 2019-12-31   三芳          23.65
#
# [242 rows x 3 columns]
# 三陽工業
#           date  name  closing_price
# 369 2019-01-02  三陽工業           19.8
# 369 2019-01-03  三陽工業           19.9
# 369 2019-01-04  三陽工業           20.1
# 369 2019-01-07  三陽工業           20.3
# 369 2019-01-08  三陽工業           20.2
# ..         ...   ...            ...
# 392 2019-12-25  三陽工業           21.1
# 392 2019-12-26  三陽工業           21.1
# 392 2019-12-27  三陽工業           21.2
# 391 2019-12-30  三陽工業           21.3
# 391 2019-12-31  三陽工業           21.3
#
# [242 rows x 3 columns]
# 上曜
#           date name  closing_price
# 163 2019-01-02   上曜          12.10
# 163 2019-01-03   上曜          12.10
# 163 2019-01-04   上曜          11.95
# 163 2019-01-07   上曜          12.05
# 163 2019-01-08   上曜          12.10
# ..         ...  ...            ...
# 185 2019-12-25   上曜          13.95
# 185 2019-12-26   上曜          14.05
# 185 2019-12-27   上曜          14.20
# 184 2019-12-30   上曜          14.55
# 184 2019-12-31   上曜          14.50
#
# [242 rows x 3 columns]
# 上海商銀
#           date  name  closing_price
# 866 2019-01-02  上海商銀          40.10
# 866 2019-01-03  上海商銀          40.10
# 866 2019-01-04  上海商銀          40.05
# 866 2019-01-07  上海商銀          40.20
# 867 2019-01-08  上海商銀          39.95
# ..         ...   ...            ...
# 899 2019-12-25  上海商銀          51.90
# 899 2019-12-26  上海商銀          52.40
# 899 2019-12-27  上海商銀          52.70
# 898 2019-12-30  上海商銀          52.20
# 898 2019-12-31  上海商銀          52.00
#
# [242 rows x 3 columns]
# 上福
#           date name  closing_price
# 878 2019-01-02   上福          28.55
# 878 2019-01-03   上福          28.75
# 878 2019-01-04   上福          28.60
# 878 2019-01-07   上福          28.60
# 879 2019-01-08   上福          28.70
# ..         ...  ...            ...
# 911 2019-12-25   上福          30.70
# 911 2019-12-26   上福          30.70
# 911 2019-12-27   上福          30.55
# 910 2019-12-30   上福          30.55
# 910 2019-12-31   上福          30.60
#
# [242 rows x 3 columns]
# 上緯投控
#           date  name  closing_price
# 767 2019-01-02  上緯投控           71.0
# 767 2019-01-03  上緯投控           69.4
# 767 2019-01-04  上緯投控           68.1
# 767 2019-01-07  上緯投控           72.0
# 768 2019-01-08  上緯投控           72.2
# ..         ...   ...            ...
# 794 2019-12-25  上緯投控           82.9
# 794 2019-12-26  上緯投控           83.0
# 794 2019-12-27  上緯投控           83.4
# 793 2019-12-30  上緯投控           83.6
# 793 2019-12-31  上緯投控           83.9
#
# [242 rows x 3 columns]
# 上銀
#           date name  closing_price
# 352 2019-01-02   上銀          219.5
# 352 2019-01-03   上銀          210.0
# 352 2019-01-04   上銀          208.5
# 352 2019-01-07   上銀          209.5
# 352 2019-01-08   上銀          203.0
# ..         ...  ...            ...
# 375 2019-12-25   上銀          278.0
# 375 2019-12-26   上銀          275.0
# 375 2019-12-27   上銀          278.0
# 374 2019-12-30   上銀          278.0
# 374 2019-12-31   上銀          281.0
#
# [242 rows x 3 columns]
# 世紀鋼
#            date name  closing_price
# 1074 2019-01-02  世紀鋼           61.1
# 1074 2019-01-03  世紀鋼           58.3
# 1074 2019-01-04  世紀鋼           52.5
# 1074 2019-01-07  世紀鋼           52.8
# 1075 2019-01-08  世紀鋼           52.5
# ...         ...  ...            ...
# 1114 2019-12-25  世紀鋼           72.6
# 1114 2019-12-26  世紀鋼           72.1
# 1114 2019-12-27  世紀鋼           72.1
# 1113 2019-12-30  世紀鋼           72.3
# 1113 2019-12-31  世紀鋼           72.2
#
# [242 rows x 3 columns]
# 世芯-KY
#           date   name  closing_price
# 752 2019-01-02  世芯-KY           69.3
# 752 2019-01-03  世芯-KY           67.6
# 752 2019-01-04  世芯-KY           69.4
# 752 2019-01-07  世芯-KY           69.4
# 753 2019-01-08  世芯-KY           70.4
# ..         ...    ...            ...
# 778 2019-12-25  世芯-KY          227.0
# 778 2019-12-26  世芯-KY          221.0
# 778 2019-12-27  世芯-KY          236.5
# 777 2019-12-30  世芯-KY          232.0
# 777 2019-12-31  世芯-KY          234.5
#
# [242 rows x 3 columns]
# 中保科
#            date name  closing_price
# 1047 2019-01-02  中保科           87.4
# 1047 2019-01-03  中保科           86.9
# 1047 2019-01-04  中保科           86.7
# 1047 2019-01-07  中保科           86.8
# 1048 2019-01-08  中保科           86.1
# ...         ...  ...            ...
# 1087 2019-12-25  中保科           88.4
# 1087 2019-12-26  中保科           88.3
# 1087 2019-12-27  中保科           88.5
# 1086 2019-12-30  中保科           88.9
# 1086 2019-12-31  中保科           88.8
#
# [242 rows x 3 columns]
# 中信中國50
#           date    name  closing_price
# 110 2019-01-02  中信中國50          20.05
# 110 2019-01-03  中信中國50          20.03
# 110 2019-01-04  中信中國50          20.03
# 110 2019-01-07  中信中國50          20.49
# 110 2019-01-08  中信中國50          20.62
# ..         ...     ...            ...
# 106 2019-12-25  中信中國50          24.40
# 106 2019-12-26  中信中國50          24.30
# 106 2019-12-27  中信中國50          24.59
# 105 2019-12-30  中信中國50          24.62
# 105 2019-12-31  中信中國50          24.28
#
# [242 rows x 3 columns]
# 中信中國50正2
#           date      name  closing_price
# 111 2019-01-02  中信中國50正2          19.34
# 111 2019-01-03  中信中國50正2          19.10
# 111 2019-01-04  中信中國50正2          19.56
# 111 2019-01-07  中信中國50正2          20.29
# 111 2019-01-08  中信中國50正2          20.48
# ..         ...       ...            ...
# 107 2019-12-25  中信中國50正2          27.31
# 107 2019-12-26  中信中國50正2          27.14
# 107 2019-12-27  中信中國50正2          27.96
# 106 2019-12-30  中信中國50正2          28.10
# 106 2019-12-31  中信中國50正2          27.83
#
# [242 rows x 3 columns]
# 中信金
#           date name  closing_price
# 617 2019-01-02  中信金          19.90
# 617 2019-01-03  中信金          20.00
# 617 2019-01-04  中信金          19.80
# 617 2019-01-07  中信金          20.10
# 618 2019-01-08  中信金          19.95
# ..         ...  ...            ...
# 642 2019-12-25  中信金          22.45
# 642 2019-12-26  中信金          22.45
# 642 2019-12-27  中信金          22.50
# 641 2019-12-30  中信金          22.50
# 641 2019-12-31  中信金          22.40
#
# [242 rows x 3 columns]
# 中信金丙特
#           date   name  closing_price
# 635 2019-05-06  中信金丙特           61.2
# 635 2019-05-07  中信金丙特           61.5
# 635 2019-05-08  中信金丙特           61.4
# 635 2019-05-09  中信金丙特           61.3
# 635 2019-05-10  中信金丙特           61.3
# ..         ...    ...            ...
# 644 2019-12-25  中信金丙特           63.1
# 644 2019-12-26  中信金丙特           63.1
# 644 2019-12-27  中信金丙特           63.3
# 643 2019-12-30  中信金丙特           63.3
# 643 2019-12-31  中信金丙特           63.4
#
# [166 rows x 3 columns]
# 中信金乙特
#           date   name  closing_price
# 618 2019-01-02  中信金乙特           63.2
# 618 2019-01-03  中信金乙特           63.2
# 618 2019-01-04  中信金乙特           63.2
# 618 2019-01-07  中信金乙特           63.3
# 619 2019-01-08  中信金乙特           63.3
# ..         ...    ...            ...
# 643 2019-12-23  中信金乙特           66.1
# 643 2019-12-25  中信金乙特           66.1
# 643 2019-12-26  中信金乙特           66.0
# 643 2019-12-27  中信金乙特           66.1
# 642 2019-12-31  中信金乙特           66.2
#
# [239 rows x 3 columns]
# 中再保
#           date name  closing_price
# 597 2019-01-02  中再保          17.10
# 597 2019-01-03  中再保          17.05
# 597 2019-01-04  中再保          17.05
# 597 2019-01-07  中再保          17.15
# 597 2019-01-08  中再保          17.15
# ..         ...  ...            ...
# 620 2019-12-25  中再保          19.60
# 620 2019-12-26  中再保          19.70
# 620 2019-12-27  中再保          19.75
# 619 2019-12-30  中再保          19.75
# 619 2019-12-31  中再保          19.85
#
# [242 rows x 3 columns]
# 中化
#           date name  closing_price
# 277 2019-01-02   中化          18.00
# 277 2019-01-03   中化          18.20
# 277 2019-01-04   中化          18.35
# 277 2019-01-07   中化          18.45
# 277 2019-01-08   中化          18.85
# ..         ...  ...            ...
# 299 2019-12-25   中化          19.15
# 299 2019-12-26   中化          19.15
# 299 2019-12-27   中化          19.20
# 298 2019-12-30   中化          19.20
# 298 2019-12-31   中化          19.25
#
# [242 rows x 3 columns]
# 中化生
#           date name  closing_price
# 307 2019-01-02  中化生          22.95
# 307 2019-01-03  中化生          23.30
# 307 2019-01-04  中化生          23.40
# 307 2019-01-07  中化生          23.40
# 307 2019-01-08  中化生          24.10
# ..         ...  ...            ...
# 328 2019-12-25  中化生          35.75
# 328 2019-12-26  中化生          35.50
# 328 2019-12-27  中化生          35.35
# 327 2019-12-30  中化生          35.10
# 327 2019-12-31  中化生          35.50
#
# [242 rows x 3 columns]
# 中和
#           date name  closing_price
# 191 2019-01-02   中和          33.05
# 191 2019-01-03   中和          32.60
# 191 2019-01-04   中和          32.80
# 191 2019-01-07   中和          32.80
# 191 2019-01-08   中和          32.95
# ..         ...  ...            ...
# 213 2019-12-25   中和          34.00
# 213 2019-12-26   中和          34.65
# 213 2019-12-27   中和          34.45
# 212 2019-12-30   中和          33.85
# 212 2019-12-31   中和          33.40
#
# [241 rows x 3 columns]
# 中壽
#           date name  closing_price
# 587 2019-01-02   中壽          27.85
# 587 2019-01-03   中壽          27.85
# 587 2019-01-04   中壽          27.60
# 587 2019-01-07   中壽          28.05
# 587 2019-01-08   中壽          27.80
# ..         ...  ...            ...
# 610 2019-12-25   中壽          25.75
# 610 2019-12-26   中壽          25.80
# 610 2019-12-27   中壽          25.80
# 609 2019-12-30   中壽          25.65
# 609 2019-12-31   中壽          25.60
#
# [242 rows x 3 columns]
# 中宇
#           date name  closing_price
# 247 2019-01-02   中宇          29.40
# 247 2019-01-04   中宇          29.60
# 247 2019-01-07   中宇          29.45
# 247 2019-01-08   中宇          30.20
# 247 2019-01-09   中宇          30.05
# ..         ...  ...            ...
# 269 2019-12-25   中宇          35.40
# 269 2019-12-26   中宇          35.30
# 269 2019-12-27   中宇          35.10
# 268 2019-12-30   中宇          35.10
# 268 2019-12-31   中宇          35.10
#
# [241 rows x 3 columns]
# 中工
#           date name  closing_price
# 526 2019-01-02   中工           7.05
# 526 2019-01-03   中工           7.05
# 526 2019-01-04   中工           7.03
# 526 2019-01-07   中工           7.16
# 526 2019-01-08   中工           7.13
# ..         ...  ...            ...
# 549 2019-12-25   中工           7.85
# 549 2019-12-26   中工           7.80
# 549 2019-12-27   中工           7.88
# 548 2019-12-30   中工           7.82
# 548 2019-12-31   中工           7.78
#
# [242 rows x 3 columns]
# 中揚光
#           date name  closing_price
# 962 2019-01-02  中揚光           89.4
# 962 2019-01-03  中揚光           86.5
# 962 2019-01-04  中揚光           82.1
# 962 2019-01-07  中揚光           84.5
# 963 2019-01-08  中揚光           87.0
# ..         ...  ...            ...
# 998 2019-12-25  中揚光           88.8
# 998 2019-12-26  中揚光           90.3
# 998 2019-12-27  中揚光           89.3
# 997 2019-12-30  中揚光           88.0
# 997 2019-12-31  中揚光           90.7
#
# [242 rows x 3 columns]
# 中櫃
#           date name  closing_price
# 557 2019-01-02   中櫃          12.55
# 557 2019-01-03   中櫃          12.45
# 557 2019-01-04   中櫃          12.45
# 557 2019-01-07   中櫃          12.45
# 557 2019-01-08   中櫃          12.45
# ..         ...  ...            ...
# 580 2019-12-25   中櫃          14.05
# 580 2019-12-26   中櫃          14.05
# 580 2019-12-27   中櫃          14.10
# 579 2019-12-30   中櫃          14.10
# 579 2019-12-31   中櫃          14.30
#
# [242 rows x 3 columns]
# 中環
#           date name  closing_price
# 389 2019-01-02   中環           6.76
# 389 2019-01-03   中環           6.87
# 389 2019-01-04   中環           6.90
# 389 2019-01-07   中環           6.94
# 389 2019-01-08   中環           6.91
# ..         ...  ...            ...
# 413 2019-12-25   中環           9.60
# 413 2019-12-26   中環           9.54
# 413 2019-12-27   中環           9.59
# 412 2019-12-30   中環           9.57
# 412 2019-12-31   中環           9.57
#
# [235 rows x 3 columns]
# 中石化
#           date name  closing_price
# 161 2019-01-02  中石化          10.90
# 161 2019-01-03  中石化          10.65
# 161 2019-01-04  中石化          10.45
# 161 2019-01-07  中石化          10.85
# 161 2019-01-08  中石化          10.70
# ..         ...  ...            ...
# 183 2019-12-25  中石化          10.15
# 183 2019-12-26  中石化           9.98
# 183 2019-12-27  中石化          10.00
# 182 2019-12-30  中石化           9.93
# 182 2019-12-31  中石化           9.80
#
# [242 rows x 3 columns]
# 中砂
#           date name  closing_price
# 255 2019-01-02   中砂           58.1
# 255 2019-01-03   中砂           57.7
# 255 2019-01-04   中砂           56.7
# 255 2019-01-07   中砂           57.6
# 255 2019-01-08   中砂           57.5
# ..         ...  ...            ...
# 277 2019-12-25   中砂           69.3
# 277 2019-12-26   中砂           68.7
# 277 2019-12-27   中砂           68.8
# 276 2019-12-30   中砂           68.6
# 276 2019-12-31   中砂           68.9
#
# [242 rows x 3 columns]
# 中碳
#           date name  closing_price
# 293 2019-01-02   中碳          135.5
# 293 2019-01-03   中碳          135.0
# 293 2019-01-04   中碳          133.5
# 293 2019-01-07   中碳          135.5
# 293 2019-01-08   中碳          135.0
# ..         ...  ...            ...
# 314 2019-12-25   中碳          122.5
# 314 2019-12-26   中碳          122.0
# 314 2019-12-27   中碳          122.5
# 313 2019-12-30   中碳          122.5
# 313 2019-12-31   中碳          122.5
#
# [242 rows x 3 columns]
# 中磊
#           date name  closing_price
# 848 2019-01-02   中磊           64.9
# 848 2019-01-03   中磊           65.4
# 848 2019-01-04   中磊           66.2
# 848 2019-01-07   中磊           66.3
# 849 2019-01-08   中磊           66.2
# ..         ...  ...            ...
# 881 2019-12-25   中磊           76.7
# 881 2019-12-26   中磊           76.4
# 881 2019-12-27   中磊           76.8
# 880 2019-12-30   中磊           77.7
# 880 2019-12-31   中磊           77.7
#
# [242 rows x 3 columns]
# 中福
#           date name  closing_price
# 187 2019-01-02   中福           5.39
# 187 2019-01-03   中福           5.38
# 187 2019-01-04   中福           5.40
# 187 2019-01-07   中福           5.41
# 187 2019-01-08   中福           5.42
# ..         ...  ...            ...
# 209 2019-12-25   中福           7.37
# 209 2019-12-26   中福           7.23
# 209 2019-12-27   中福           7.31
# 208 2019-12-30   中福           7.33
# 208 2019-12-31   中福           7.30
#
# [242 rows x 3 columns]
# 中租-KY
#           date   name  closing_price
# 865 2019-01-02  中租-KY           98.1
# 865 2019-01-03  中租-KY           97.0
# 865 2019-01-04  中租-KY           98.0
# 865 2019-01-07  中租-KY           99.7
# 866 2019-01-08  中租-KY          100.5
# ..         ...    ...            ...
# 898 2019-12-25  中租-KY          138.5
# 898 2019-12-26  中租-KY          138.5
# 898 2019-12-27  中租-KY          139.5
# 897 2019-12-30  中租-KY          140.5
# 897 2019-12-31  中租-KY          138.0
#
# [242 rows x 3 columns]
# 中纖
#           date name  closing_price
# 289 2019-01-02   中纖          10.05
# 289 2019-01-03   中纖          10.00
# 289 2019-01-04   中纖           9.98
# 289 2019-01-07   中纖          10.15
# 289 2019-01-08   中纖          10.10
# ..         ...  ...            ...
# 310 2019-12-25   中纖           8.19
# 310 2019-12-26   中纖           8.13
# 310 2019-12-27   中纖           8.16
# 309 2019-12-30   中纖           8.27
# 309 2019-12-31   中纖           8.30
#
# [242 rows x 3 columns]
# 中聯資源
#            date  name  closing_price
# 1057 2019-01-02  中聯資源           50.5
# 1057 2019-01-03  中聯資源           50.9
# 1057 2019-01-04  中聯資源           50.7
# 1057 2019-01-07  中聯資源           51.0
# 1058 2019-01-08  中聯資源           50.9
# ...         ...   ...            ...
# 1097 2019-12-25  中聯資源           50.4
# 1097 2019-12-26  中聯資源           50.3
# 1097 2019-12-27  中聯資源           50.3
# 1096 2019-12-30  中聯資源           50.3
# 1096 2019-12-31  中聯資源           50.3
#
# [242 rows x 3 columns]
# 中興電
#           date name  closing_price
# 229 2019-01-02  中興電          19.25
# 229 2019-01-03  中興電          19.15
# 229 2019-01-04  中興電          19.05
# 229 2019-01-07  中興電          19.55
# 229 2019-01-08  中興電          19.55
# ..         ...  ...            ...
# 251 2019-12-25  中興電          22.70
# 251 2019-12-26  中興電          22.75
# 251 2019-12-27  中興電          22.80
# 250 2019-12-30  中興電          22.90
# 250 2019-12-31  中興電          24.30
#
# [242 rows x 3 columns]
# 中航
#           date name  closing_price
# 556 2019-01-02   中航          31.00
# 556 2019-01-03   中航          31.05
# 556 2019-01-04   中航          31.05
# 556 2019-01-07   中航          31.10
# 556 2019-01-08   中航          31.00
# ..         ...  ...            ...
# 579 2019-12-25   中航          29.75
# 579 2019-12-26   中航          29.70
# 579 2019-12-27   中航          29.90
# 578 2019-12-30   中航          29.70
# 578 2019-12-31   中航          29.75
#
# [242 rows x 3 columns]
# 中華
#           date name  closing_price
# 368 2019-01-02   中華          23.75
# 368 2019-01-03   中華          23.65
# 368 2019-01-04   中華          23.65
# 368 2019-01-07   中華          24.05
# 368 2019-01-08   中華          23.70
# ..         ...  ...            ...
# 391 2019-12-25   中華          38.70
# 391 2019-12-26   中華          39.10
# 391 2019-12-27   中華          39.10
# 390 2019-12-30   中華          39.00
# 390 2019-12-31   中華          39.10
#
# [236 rows x 3 columns]
# 中華化
#           date name  closing_price
# 297 2019-01-02  中華化          14.10
# 297 2019-01-03  中華化          14.05
# 297 2019-01-04  中華化          13.90
# 297 2019-01-07  中華化          14.00
# 297 2019-01-08  中華化          14.00
# ..         ...  ...            ...
# 318 2019-12-25  中華化          11.75
# 318 2019-12-26  中華化          11.80
# 318 2019-12-27  中華化          11.75
# 317 2019-12-30  中華化          11.70
# 317 2019-12-31  中華化          11.75
#
# [242 rows x 3 columns]
# 中華電
#           date name  closing_price
# 449 2019-01-02  中華電          107.0
# 449 2019-01-03  中華電          107.0
# 449 2019-01-04  中華電          107.5
# 449 2019-01-07  中華電          108.0
# 449 2019-01-08  中華電          107.0
# ..         ...  ...            ...
# 473 2019-12-25  中華電          110.5
# 473 2019-12-26  中華電          111.0
# 473 2019-12-27  中華電          111.5
# 472 2019-12-30  中華電          111.0
# 472 2019-12-31  中華電          110.0
#
# [242 rows x 3 columns]
# 中視
#            date name  closing_price
# 1055 2019-01-02   中視           5.12
# 1055 2019-01-03   中視           5.12
# 1055 2019-01-04   中視           5.19
# 1057 2019-01-09   中視           5.00
# 1057 2019-01-10   中視           5.00
# ...         ...  ...            ...
# 1095 2019-12-25   中視           4.95
# 1095 2019-12-26   中視           4.84
# 1095 2019-12-27   中視           4.84
# 1094 2019-12-30   中視           4.86
# 1094 2019-12-31   中視           5.00
#
# [206 rows x 3 columns]
# 中釉
#           date name  closing_price
# 317 2019-01-02   中釉          10.50
# 317 2019-01-03   中釉          10.45
# 317 2019-01-04   中釉          10.40
# 317 2019-01-07   中釉          10.40
# 317 2019-01-08   中釉          10.40
# ..         ...  ...            ...
# 339 2019-12-25   中釉          11.85
# 339 2019-12-26   中釉          11.80
# 339 2019-12-27   中釉          11.80
# 338 2019-12-30   中釉          11.80
# 338 2019-12-31   中釉          11.85
#
# [242 rows x 3 columns]
# 中鋼
#           date name  closing_price
# 327 2019-01-02   中鋼          24.00
# 327 2019-01-03   中鋼          24.15
# 327 2019-01-04   中鋼          24.20
# 327 2019-01-07   中鋼          24.45
# 327 2019-01-08   中鋼          24.50
# ..         ...  ...            ...
# 349 2019-12-25   中鋼          23.80
# 349 2019-12-26   中鋼          23.90
# 349 2019-12-27   中鋼          23.95
# 348 2019-12-30   中鋼          24.00
# 348 2019-12-31   中鋼          23.90
#
# [242 rows x 3 columns]
# 中鋼構
#           date name  closing_price
# 335 2019-01-02  中鋼構          25.80
# 335 2019-01-03  中鋼構          25.65
# 335 2019-01-04  中鋼構          25.25
# 335 2019-01-07  中鋼構          25.55
# 335 2019-01-08  中鋼構          25.80
# ..         ...  ...            ...
# 357 2019-12-25  中鋼構          24.80
# 357 2019-12-26  中鋼構          24.85
# 357 2019-12-27  中鋼構          24.85
# 356 2019-12-30  中鋼構          25.30
# 356 2019-12-31  中鋼構          25.10
#
# [242 rows x 3 columns]
# 中鋼特
#           date name  closing_price
# 328 2019-01-02  中鋼特          43.40
# 328 2019-01-03  中鋼特          43.40
# 328 2019-01-04  中鋼特          43.40
# 328 2019-01-07  中鋼特          43.50
# 328 2019-01-08  中鋼特          43.75
# ..         ...  ...            ...
# 350 2019-12-25  中鋼特          54.20
# 350 2019-12-26  中鋼特          54.20
# 350 2019-12-27  中鋼特          54.30
# 349 2019-12-30  中鋼特          54.30
# 349 2019-12-31  中鋼特          54.50
#
# [241 rows x 3 columns]
# 中電
#           date name  closing_price
# 269 2019-01-02   中電           9.09
# 269 2019-01-03   中電           9.09
# 269 2019-01-04   中電           9.03
# 269 2019-01-07   中電           9.50
# 269 2019-01-08   中電           9.42
# ..         ...  ...            ...
# 291 2019-12-25   中電          10.95
# 291 2019-12-26   中電          11.10
# 291 2019-12-27   中電          11.15
# 290 2019-12-30   中電          11.20
# 290 2019-12-31   中電          11.10
#
# [236 rows x 3 columns]
# 中鴻
#           date name  closing_price
# 336 2019-01-02   中鴻          10.95
# 336 2019-01-03   中鴻          10.70
# 336 2019-01-04   中鴻          10.35
# 336 2019-01-07   中鴻          10.75
# 336 2019-01-08   中鴻          10.70
# ..         ...  ...            ...
# 358 2019-12-25   中鴻          10.25
# 358 2019-12-26   中鴻          10.15
# 358 2019-12-27   中鴻          10.35
# 357 2019-12-30   中鴻          10.60
# 357 2019-12-31   中鴻          10.65
#
# [242 rows x 3 columns]
# 中鼎
#            date name  closing_price
# 1059 2019-01-02   中鼎          44.40
# 1059 2019-01-03   中鼎          44.40
# 1059 2019-01-04   中鼎          45.15
# 1059 2019-01-07   中鼎          46.10
# 1060 2019-01-08   中鼎          46.40
# ...         ...  ...            ...
# 1099 2019-12-25   中鼎          37.65
# 1099 2019-12-26   中鼎          37.80
# 1099 2019-12-27   中鼎          38.00
# 1098 2019-12-30   中鼎          38.00
# 1098 2019-12-31   中鼎          38.10
#
# [242 rows x 3 columns]
# 乙盛-KY
#           date   name  closing_price
# 839 2019-01-02  乙盛-KY          30.60
# 839 2019-01-03  乙盛-KY          30.50
# 839 2019-01-04  乙盛-KY          30.00
# 839 2019-01-07  乙盛-KY          30.10
# 840 2019-01-08  乙盛-KY          30.30
# ..         ...    ...            ...
# 872 2019-12-25  乙盛-KY          37.00
# 872 2019-12-26  乙盛-KY          36.90
# 872 2019-12-27  乙盛-KY          37.00
# 871 2019-12-30  乙盛-KY          37.15
# 871 2019-12-31  乙盛-KY          37.00
#
# [242 rows x 3 columns]
# 事欣科
#           date name  closing_price
# 814 2019-01-02  事欣科          28.90
# 814 2019-01-03  事欣科          28.75
# 814 2019-01-04  事欣科          28.15
# 814 2019-01-07  事欣科          28.45
# 815 2019-01-08  事欣科          28.50
# ..         ...  ...            ...
# 846 2019-12-25  事欣科          34.30
# 846 2019-12-26  事欣科          34.05
# 846 2019-12-27  事欣科          34.10
# 845 2019-12-30  事欣科          33.85
# 845 2019-12-31  事欣科          34.05
#
# [242 rows x 3 columns]
# 云辰
#           date name  closing_price
# 436 2019-01-02   云辰          10.70
# 436 2019-01-03   云辰          11.15
# 436 2019-01-04   云辰          12.10
# 436 2019-01-07   云辰          11.95
# 436 2019-01-08   云辰          13.10
# ..         ...  ...            ...
# 460 2019-12-25   云辰          11.00
# 460 2019-12-26   云辰          11.00
# 460 2019-12-27   云辰          11.20
# 459 2019-12-30   云辰          10.95
# 459 2019-12-31   云辰          11.05
#
# [242 rows x 3 columns]
# 互億
#           date name  closing_price
# 891 2019-01-02   互億          12.95
# 891 2019-01-03   互億          11.85
# 891 2019-01-04   互億          11.90
# 892 2019-01-08   互億          11.80
# 893 2019-01-09   互億          12.20
# ..         ...  ...            ...
# 925 2019-12-25   互億          18.60
# 925 2019-12-26   互億          18.85
# 925 2019-12-27   互億          18.60
# 924 2019-12-30   互億          18.60
# 924 2019-12-31   互億          18.85
#
# [238 rows x 3 columns]
# 互盛電
#           date name  closing_price
# 466 2019-01-02  互盛電          42.20
# 466 2019-01-03  互盛電          41.75
# 466 2019-01-04  互盛電          41.90
# 466 2019-01-07  互盛電          42.10
# 466 2019-01-08  互盛電          42.00
# ..         ...  ...            ...
# 490 2019-12-25  互盛電          55.50
# 490 2019-12-26  互盛電          56.10
# 490 2019-12-27  互盛電          56.90
# 489 2019-12-30  互盛電          56.30
# 489 2019-12-31  互盛電          56.20
#
# [242 rows x 3 columns]
# 五鼎
#           date name  closing_price
# 301 2019-01-02   五鼎          29.85
# 301 2019-01-03   五鼎          30.55
# 301 2019-01-04   五鼎          30.40
# 301 2019-01-07   五鼎          31.20
# 301 2019-01-08   五鼎          31.50
# ..         ...  ...            ...
# 322 2019-12-25   五鼎          28.60
# 322 2019-12-26   五鼎          28.45
# 322 2019-12-27   五鼎          28.35
# 321 2019-12-30   五鼎          28.25
# 321 2019-12-31   五鼎          28.35
#
# [242 rows x 3 columns]
# 亞光
#           date name  closing_price
# 650 2019-01-02   亞光           67.0
# 650 2019-01-03   亞光           65.3
# 650 2019-01-04   亞光           64.0
# 650 2019-01-07   亞光           66.4
# 651 2019-01-08   亞光           68.5
# ..         ...  ...            ...
# 677 2019-12-25   亞光          101.5
# 677 2019-12-26   亞光          106.5
# 677 2019-12-27   亞光          106.0
# 676 2019-12-30   亞光          105.5
# 676 2019-12-31   亞光          108.0
#
# [242 rows x 3 columns]
# 亞力
#           date name  closing_price
# 230 2019-01-02   亞力          13.40
# 230 2019-01-03   亞力          13.05
# 230 2019-01-04   亞力          13.05
# 230 2019-01-07   亞力          13.20
# 230 2019-01-08   亞力          13.25
# ..         ...  ...            ...
# 252 2019-12-25   亞力          17.80
# 252 2019-12-26   亞力          17.75
# 252 2019-12-27   亞力          17.80
# 251 2019-12-30   亞力          17.80
# 251 2019-12-31   亞力          17.90
#
# [242 rows x 3 columns]
# 亞太電
#           date name  closing_price
# 757 2019-01-02  亞太電           7.04
# 757 2019-01-03  亞太電           7.11
# 757 2019-01-04  亞太電           6.99
# 757 2019-01-07  亞太電           7.04
# 758 2019-01-08  亞太電           7.02
# ..         ...  ...            ...
# 783 2019-12-25  亞太電           7.80
# 783 2019-12-26  亞太電           7.71
# 783 2019-12-27  亞太電           7.66
# 782 2019-12-30  亞太電           7.64
# 782 2019-12-31  亞太電           7.53
#
# [242 rows x 3 columns]
# 亞崴
#           date name  closing_price
# 243 2019-01-02   亞崴          29.50
# 243 2019-01-03   亞崴          29.50
# 243 2019-01-04   亞崴          29.30
# 243 2019-01-07   亞崴          29.55
# 243 2019-01-08   亞崴          29.45
# ..         ...  ...            ...
# 265 2019-12-25   亞崴          29.85
# 265 2019-12-26   亞崴          29.70
# 265 2019-12-27   亞崴          29.65
# 264 2019-12-30   亞崴          30.35
# 264 2019-12-31   亞崴          30.20
#
# [239 rows x 3 columns]
# 亞弘電
#           date name  closing_price
# 901 2019-01-02  亞弘電          29.70
# 901 2019-01-03  亞弘電          29.65
# 901 2019-01-04  亞弘電          29.55
# 901 2019-01-07  亞弘電          29.55
# 902 2019-01-08  亞弘電          29.50
# ..         ...  ...            ...
# 935 2019-12-25  亞弘電          35.20
# 935 2019-12-26  亞弘電          35.20
# 935 2019-12-27  亞弘電          35.20
# 934 2019-12-30  亞弘電          35.15
# 934 2019-12-31  亞弘電          35.40
#
# [242 rows x 3 columns]
# 亞德客-KY
#           date    name  closing_price
# 261 2019-01-02  亞德客-KY          300.0
# 261 2019-01-03  亞德客-KY          292.0
# 261 2019-01-04  亞德客-KY          287.5
# 261 2019-01-07  亞德客-KY          304.5
# 261 2019-01-08  亞德客-KY          292.0
# ..         ...     ...            ...
# 283 2019-12-25  亞德客-KY          436.0
# 283 2019-12-26  亞德客-KY          435.0
# 283 2019-12-27  亞德客-KY          441.5
# 282 2019-12-30  亞德客-KY          447.0
# 282 2019-12-31  亞德客-KY          466.5
#
# [242 rows x 3 columns]
# 亞泥
#           date name  closing_price
# 123 2019-01-02   亞泥          33.80
# 123 2019-01-03   亞泥          33.90
# 123 2019-01-04   亞泥          33.85
# 123 2019-01-07   亞泥          34.85
# 123 2019-01-08   亞泥          34.65
# ..         ...  ...            ...
# 146 2019-12-25   亞泥          47.25
# 146 2019-12-26   亞泥          47.30
# 146 2019-12-27   亞泥          47.70
# 145 2019-12-30   亞泥          48.15
# 145 2019-12-31   亞泥          47.95
#
# [242 rows x 3 columns]
# 亞翔
#           date name  closing_price
# 881 2019-01-02   亞翔          25.85
# 881 2019-01-03   亞翔          25.50
# 881 2019-01-04   亞翔          25.15
# 881 2019-01-07   亞翔          25.60
# 882 2019-01-08   亞翔          25.50
# ..         ...  ...            ...
# 915 2019-12-25   亞翔          31.85
# 915 2019-12-26   亞翔          31.85
# 915 2019-12-27   亞翔          31.60
# 914 2019-12-30   亞翔          31.70
# 914 2019-12-31   亞翔          31.45
#
# [242 rows x 3 columns]
# 亞聚
#           date name  closing_price
# 155 2019-01-02   亞聚          13.00
# 155 2019-01-03   亞聚          12.95
# 155 2019-01-04   亞聚          12.95
# 155 2019-01-07   亞聚          13.10
# 155 2019-01-08   亞聚          13.15
# ..         ...  ...            ...
# 177 2019-12-25   亞聚          15.95
# 177 2019-12-26   亞聚          15.85
# 177 2019-12-27   亞聚          15.95
# 176 2019-12-30   亞聚          15.90
# 176 2019-12-31   亞聚          15.80
#
# [242 rows x 3 columns]
# 亞航
#           date name  closing_price
# 563 2019-01-02   亞航          25.40
# 563 2019-01-03   亞航          25.00
# 563 2019-01-04   亞航          24.30
# 563 2019-01-07   亞航          24.90
# 563 2019-01-08   亞航          24.00
# ..         ...  ...            ...
# 586 2019-12-25   亞航          18.70
# 586 2019-12-26   亞航          18.65
# 586 2019-12-27   亞航          18.65
# 585 2019-12-30   亞航          18.40
# 585 2019-12-31   亞航          18.60
#
# [242 rows x 3 columns]
# 亞諾法
#           date name  closing_price
# 774 2019-01-02  亞諾法          29.30
# 774 2019-01-03  亞諾法          29.35
# 774 2019-01-04  亞諾法          29.40
# 774 2019-01-07  亞諾法          29.35
# 775 2019-01-08  亞諾法          29.30
# ..         ...  ...            ...
# 801 2019-12-25  亞諾法          25.85
# 801 2019-12-26  亞諾法          25.65
# 801 2019-12-27  亞諾法          25.55
# 800 2019-12-30  亞諾法          25.35
# 800 2019-12-31  亞諾法          25.40
#
# [242 rows x 3 columns]
# 京元電子
#           date  name  closing_price
# 477 2019-01-02  京元電子          23.05
# 477 2019-01-03  京元電子          22.40
# 477 2019-01-04  京元電子          21.35
# 477 2019-01-07  京元電子          21.60
# 477 2019-01-08  京元電子          21.80
# ..         ...   ...            ...
# 501 2019-12-25  京元電子          38.00
# 501 2019-12-26  京元電子          37.45
# 501 2019-12-27  京元電子          37.45
# 500 2019-12-30  京元電子          37.95
# 500 2019-12-31  京元電子          37.55
#
# [242 rows x 3 columns]
# 京城
#           date name  closing_price
# 529 2019-01-02   京城          26.10
# 529 2019-01-03   京城          25.85
# 529 2019-01-04   京城          25.90
# 529 2019-01-07   京城          26.20
# 529 2019-01-08   京城          25.95
# ..         ...  ...            ...
# 552 2019-12-25   京城          30.95
# 552 2019-12-26   京城          30.70
# 552 2019-12-27   京城          31.00
# 551 2019-12-30   京城          30.80
# 551 2019-12-31   京城          31.05
#
# [242 rows x 3 columns]
# 京城樂富R1
#           date    name  closing_price
# 121 2019-01-02  京城樂富R1          10.03
# 121 2019-01-03  京城樂富R1          10.01
# 121 2019-01-04  京城樂富R1          10.01
# 121 2019-01-07  京城樂富R1          10.02
# 121 2019-01-08  京城樂富R1          10.01
# ..         ...     ...            ...
# 134 2019-12-25  京城樂富R1          10.20
# 134 2019-12-26  京城樂富R1          10.19
# 134 2019-12-27  京城樂富R1          10.18
# 133 2019-12-30  京城樂富R1          10.19
# 133 2019-12-31  京城樂富R1          10.25
#
# [242 rows x 3 columns]
# 京城銀
#           date name  closing_price
# 583 2019-01-02  京城銀          28.70
# 583 2019-01-03  京城銀          28.05
# 583 2019-01-04  京城銀          28.20
# 583 2019-01-07  京城銀          28.50
# 583 2019-01-08  京城銀          28.40
# ..         ...  ...            ...
# 606 2019-12-25  京城銀          34.05
# 606 2019-12-26  京城銀          33.70
# 606 2019-12-27  京城銀          33.65
# 605 2019-12-30  京城銀          33.70
# 605 2019-12-31  京城銀          33.50
#
# [242 rows x 3 columns]
# 京鼎
#           date name  closing_price
# 715 2019-01-02   京鼎          132.0
# 715 2019-01-03   京鼎          129.5
# 715 2019-01-04   京鼎          125.5
# 715 2019-01-07   京鼎          133.0
# 716 2019-01-08   京鼎          131.5
# ..         ...  ...            ...
# 742 2019-12-25   京鼎          184.0
# 742 2019-12-26   京鼎          177.5
# 742 2019-12-27   京鼎          184.0
# 741 2019-12-30   京鼎          179.0
# 741 2019-12-31   京鼎          178.0
#
# [242 rows x 3 columns]
# 仁寶
#           date name  closing_price
# 390 2019-01-02   仁寶          17.45
# 390 2019-01-03   仁寶          17.40
# 390 2019-01-04   仁寶          17.10
# 390 2019-01-07   仁寶          17.45
# 390 2019-01-08   仁寶          17.35
# ..         ...  ...            ...
# 414 2019-12-25   仁寶          18.95
# 414 2019-12-26   仁寶          19.00
# 414 2019-12-27   仁寶          19.00
# 413 2019-12-30   仁寶          18.95
# 413 2019-12-31   仁寶          18.85
#
# [242 rows x 3 columns]
# 今國光
#           date name  closing_price
# 905 2019-01-02  今國光          27.75
# 905 2019-01-03  今國光          27.40
# 905 2019-01-04  今國光          26.80
# 905 2019-01-07  今國光          28.00
# 906 2019-01-08  今國光          27.90
# ..         ...  ...            ...
# 939 2019-12-25  今國光          31.40
# 939 2019-12-26  今國光          31.70
# 939 2019-12-27  今國光          31.00
# 938 2019-12-30  今國光          31.45
# 938 2019-12-31  今國光          31.55
#
# [242 rows x 3 columns]
# 今皓
#           date name  closing_price
# 643 2019-01-02   今皓           7.22
# 643 2019-01-03   今皓           7.19
# 643 2019-01-04   今皓           6.96
# 643 2019-01-07   今皓           7.08
# 644 2019-01-08   今皓           7.11
# ..         ...  ...            ...
# 670 2019-12-25   今皓           6.26
# 670 2019-12-26   今皓           6.49
# 670 2019-12-27   今皓           6.66
# 669 2019-12-30   今皓           6.59
# 669 2019-12-31   今皓           6.60
#
# [242 rows x 3 columns]
# 仲琦
#           date name  closing_price
# 454 2019-01-02   仲琦          19.50
# 454 2019-01-03   仲琦          19.55
# 454 2019-01-04   仲琦          19.90
# 454 2019-01-07   仲琦          20.00
# 454 2019-01-08   仲琦          20.85
# ..         ...  ...            ...
# 478 2019-12-25   仲琦          27.95
# 478 2019-12-26   仲琦          28.10
# 478 2019-12-27   仲琦          29.05
# 477 2019-12-30   仲琦          28.30
# 477 2019-12-31   仲琦          28.00
#
# [242 rows x 3 columns]
# 伸興
#           date name  closing_price
# 254 2019-01-02   伸興          135.0
# 254 2019-01-03   伸興          135.0
# 254 2019-01-04   伸興          136.0
# 254 2019-01-07   伸興          136.0
# 254 2019-01-08   伸興          136.5
# ..         ...  ...            ...
# 276 2019-12-25   伸興          133.0
# 276 2019-12-26   伸興          133.0
# 276 2019-12-27   伸興          133.0
# 275 2019-12-30   伸興          132.5
# 275 2019-12-31   伸興          132.5
#
# [242 rows x 3 columns]
# 佐登-KY
#           date   name  closing_price
# 782 2019-01-02  佐登-KY          118.0
# 782 2019-01-03  佐登-KY          115.5
# 782 2019-01-04  佐登-KY          117.5
# 782 2019-01-07  佐登-KY          123.5
# 783 2019-01-08  佐登-KY          123.0
# ..         ...    ...            ...
# 809 2019-12-25  佐登-KY          118.0
# 809 2019-12-26  佐登-KY          117.0
# 809 2019-12-27  佐登-KY          121.0
# 808 2019-12-30  佐登-KY          124.0
# 808 2019-12-31  佐登-KY          123.0
#
# [242 rows x 3 columns]
# 佰鴻
#           date name  closing_price
# 661 2019-01-02   佰鴻          10.50
# 661 2019-01-03   佰鴻          10.35
# 661 2019-01-04   佰鴻          10.15
# 661 2019-01-07   佰鴻          10.30
# 662 2019-01-08   佰鴻          10.35
# ..         ...  ...            ...
# 688 2019-12-25   佰鴻          16.80
# 688 2019-12-26   佰鴻          16.80
# 688 2019-12-27   佰鴻          16.75
# 687 2019-12-30   佰鴻          16.80
# 687 2019-12-31   佰鴻          16.70
#
# [242 rows x 3 columns]
# 佳世達
#           date name  closing_price
# 407 2019-01-02  佳世達          19.70
# 407 2019-01-03  佳世達          19.85
# 407 2019-01-04  佳世達          20.25
# 407 2019-01-07  佳世達          20.15
# 407 2019-01-08  佳世達          20.05
# ..         ...  ...            ...
# 431 2019-12-25  佳世達          21.65
# 431 2019-12-26  佳世達          21.40
# 431 2019-12-27  佳世達          21.35
# 430 2019-12-30  佳世達          21.20
# 430 2019-12-31  佳世達          21.30
#
# [242 rows x 3 columns]
# 佳凌
#           date name  closing_price
# 829 2019-01-02   佳凌          31.20
# 829 2019-01-03   佳凌          30.60
# 829 2019-01-04   佳凌          30.10
# 829 2019-01-07   佳凌          31.00
# 830 2019-01-08   佳凌          31.25
# ..         ...  ...            ...
# 862 2019-12-25   佳凌          27.15
# 862 2019-12-26   佳凌          27.20
# 862 2019-12-27   佳凌          27.25
# 861 2019-12-30   佳凌          28.30
# 861 2019-12-31   佳凌          28.40
#
# [242 rows x 3 columns]
# 佳和
#           date name  closing_price
# 200 2019-01-02   佳和           4.92
# 200 2019-01-03   佳和           4.82
# 200 2019-01-04   佳和           4.92
# 200 2019-01-07   佳和           4.97
# 200 2019-01-08   佳和           4.95
# ..         ...  ...            ...
# 222 2019-12-25   佳和          13.10
# 222 2019-12-26   佳和          12.90
# 222 2019-12-27   佳和          13.00
# 221 2019-12-30   佳和          12.35
# 221 2019-12-31   佳和          12.20
#
# [240 rows x 3 columns]
# 佳大
#           date name  closing_price
# 349 2019-01-02   佳大           9.54
# 349 2019-01-03   佳大           9.33
# 349 2019-01-04   佳大           9.33
# 349 2019-01-07   佳大           9.53
# 349 2019-01-08   佳大           9.45
# ..         ...  ...            ...
# 372 2019-12-25   佳大           8.97
# 372 2019-12-26   佳大           9.05
# 372 2019-12-27   佳大           9.03
# 371 2019-12-30   佳大           9.06
# 371 2019-12-31   佳大           9.02
#
# [242 rows x 3 columns]
# 佳必琪
#           date name  closing_price
# 900 2019-01-02  佳必琪          26.95
# 900 2019-01-03  佳必琪          26.50
# 900 2019-01-04  佳必琪          26.30
# 900 2019-01-07  佳必琪          26.55
# 901 2019-01-08  佳必琪          26.35
# ..         ...  ...            ...
# 934 2019-12-25  佳必琪          33.00
# 934 2019-12-26  佳必琪          32.75
# 934 2019-12-27  佳必琪          32.75
# 933 2019-12-30  佳必琪          32.95
# 933 2019-12-31  佳必琪          32.95
#
# [242 rows x 3 columns]
# 佳格
# ...
# 797 2019-12-31   雃博          24.30
#
# [242 rows x 3 columns]
# 雄獅
#           date name  closing_price
# 579 2019-01-02   雄獅           86.2
# 579 2019-01-03   雄獅           85.9
# 579 2019-01-04   雄獅           85.2
# 579 2019-01-07   雄獅           86.3
# 579 2019-01-08   雄獅           86.1
# ..         ...  ...            ...
# 602 2019-12-25   雄獅           85.7
# 602 2019-12-26   雄獅           85.7
# 602 2019-12-27   雄獅           85.8
# 601 2019-12-30   雄獅           85.3
# 601 2019-12-31   雄獅           85.0
#
# [242 rows x 3 columns]
# 集盛
#           date name  closing_price
# 205 2019-01-02   集盛           8.88
# 205 2019-01-03   集盛           8.80
# 205 2019-01-04   集盛           8.66
# 205 2019-01-07   集盛           8.84
# 205 2019-01-08   集盛           8.81
# ..         ...  ...            ...
# 227 2019-12-25   集盛           8.10
# 227 2019-12-26   集盛           8.09
# 227 2019-12-27   集盛           8.07
# 226 2019-12-30   集盛           8.02
# 226 2019-12-31   集盛           8.00
#
# [242 rows x 3 columns]
# 雙鍵
#           date name  closing_price
# 807 2019-01-02   雙鍵           77.9
# 807 2019-01-03   雙鍵           77.8
# 807 2019-01-04   雙鍵           77.2
# 807 2019-01-07   雙鍵           77.8
# 808 2019-01-08   雙鍵           79.0
# ..         ...  ...            ...
# 839 2019-12-25   雙鍵           67.9
# 839 2019-12-26   雙鍵           67.9
# 839 2019-12-27   雙鍵           67.9
# 838 2019-12-30   雙鍵           68.2
# 838 2019-12-31   雙鍵           68.3
#
# [241 rows x 3 columns]
# 雲品
#           date name  closing_price
# 581 2019-01-02   雲品           62.5
# 581 2019-01-03   雲品           62.8
# 581 2019-01-04   雲品           62.8
# 581 2019-01-07   雲品           63.0
# 581 2019-01-08   雲品           63.6
# ..         ...  ...            ...
# 604 2019-12-25   雲品           51.2
# 604 2019-12-26   雲品           51.2
# 604 2019-12-27   雲品           51.2
# 603 2019-12-30   雲品           50.8
# 603 2019-12-31   雲品           50.4
#
# [241 rows x 3 columns]
# 零壹
#           date name  closing_price
# 659 2019-01-02   零壹          19.75
# 659 2019-01-03   零壹          19.75
# 659 2019-01-04   零壹          19.50
# 659 2019-01-07   零壹          20.40
# 660 2019-01-08   零壹          20.20
# ..         ...  ...            ...
# 686 2019-12-25   零壹          30.00
# 686 2019-12-26   零壹          30.00
# 686 2019-12-27   零壹          30.35
# 685 2019-12-30   零壹          30.40
# 685 2019-12-31   零壹          30.15
#
# [242 rows x 3 columns]
# 雷虎
#            date name  closing_price
# 970  2019-01-02   雷虎           8.06
# 970  2019-01-03   雷虎           8.05
# 970  2019-01-04   雷虎           8.12
# 970  2019-01-07   雷虎           8.29
# 971  2019-01-08   雷虎           8.18
# ...         ...  ...            ...
# 1011 2019-12-25   雷虎          10.20
# 1011 2019-12-26   雷虎          10.15
# 1011 2019-12-27   雷虎          10.05
# 1010 2019-12-30   雷虎           9.86
# 1010 2019-12-31   雷虎          10.20
#
# [242 rows x 3 columns]
# 震旦行
#           date name  closing_price
# 424 2019-01-02  震旦行           95.8
# 424 2019-01-03  震旦行           95.0
# 424 2019-01-04  震旦行           93.9
# 424 2019-01-07  震旦行           94.0
# 424 2019-01-08  震旦行           93.1
# ..         ...  ...            ...
# 448 2019-12-25  震旦行           90.3
# 448 2019-12-26  震旦行           90.0
# 448 2019-12-27  震旦行           90.5
# 447 2019-12-30  震旦行           90.1
# 447 2019-12-31  震旦行           90.1
#
# [242 rows x 3 columns]
# 順天
#           date name  closing_price
# 857 2019-01-02   順天          20.75
# 857 2019-01-03   順天          20.75
# 857 2019-01-04   順天          20.55
# 857 2019-01-07   順天          20.65
# 858 2019-01-08   順天          21.00
# ..         ...  ...            ...
# 890 2019-12-25   順天          23.35
# 890 2019-12-26   順天          23.30
# 890 2019-12-27   順天          23.40
# 889 2019-12-30   順天          23.45
# 889 2019-12-31   順天          23.30
#
# [242 rows x 3 columns]
# 順德
#           date name  closing_price
# 406 2019-01-02   順德           67.9
# 406 2019-01-03   順德           66.8
# 406 2019-01-04   順德           65.5
# 406 2019-01-07   順德           66.6
# 406 2019-01-08   順德           68.5
# ..         ...  ...            ...
# 430 2019-12-25   順德           66.7
# 430 2019-12-26   順德           67.1
# 430 2019-12-27   順德           66.5
# 429 2019-12-30   順德           65.4
# 429 2019-12-31   順德           64.9
#
# [242 rows x 3 columns]
# 飛宏
#           date name  closing_price
# 484 2019-01-02   飛宏          10.30
# 484 2019-01-03   飛宏          10.25
# 484 2019-01-04   飛宏          10.10
# 484 2019-01-07   飛宏          10.25
# 484 2019-01-08   飛宏          10.25
# ..         ...  ...            ...
# 508 2019-12-25   飛宏          10.20
# 508 2019-12-26   飛宏          10.25
# 508 2019-12-27   飛宏          10.20
# 507 2019-12-30   飛宏          10.30
# 507 2019-12-31   飛宏          10.20
#
# [242 rows x 3 columns]
# 飛捷
#           date name  closing_price
# 904 2019-01-02   飛捷           67.2
# 904 2019-01-03   飛捷           67.1
# 904 2019-01-04   飛捷           67.1
# 904 2019-01-07   飛捷           67.5
# 905 2019-01-08   飛捷           67.5
# ..         ...  ...            ...
# 938 2019-12-25   飛捷           71.5
# 938 2019-12-26   飛捷           72.1
# 938 2019-12-27   飛捷           72.2
# 937 2019-12-30   飛捷           72.1
# 937 2019-12-31   飛捷           72.0
#
# [242 rows x 3 columns]
# 首利
#           date name  closing_price
# 217 2019-01-02   首利           4.99
# 217 2019-01-03   首利           5.01
# 217 2019-01-04   首利           4.93
# 217 2019-01-07   首利           5.04
# 217 2019-01-08   首利           4.93
# ..         ...  ...            ...
# 239 2019-12-25   首利           2.25
# 239 2019-12-26   首利           2.39
# 239 2019-12-27   首利           2.43
# 238 2019-12-30   首利           2.51
# 238 2019-12-31   首利           2.64
#
# [242 rows x 3 columns]
# 駐龍
#           date name  closing_price
# 820 2019-09-10   駐龍          160.5
# 818 2019-09-11   駐龍          157.5
# 818 2019-09-12   駐龍          156.5
# 817 2019-09-16   駐龍          150.0
# 819 2019-09-17   駐龍          151.0
# ..         ...  ...            ...
# 829 2019-12-25   駐龍          125.0
# 829 2019-12-26   駐龍          124.0
# 829 2019-12-27   駐龍          126.5
# 828 2019-12-30   駐龍          128.0
# 828 2019-12-31   駐龍          129.5
#
# [77 rows x 3 columns]
# 騰輝電子-KY
#            date     name  closing_price
# 978  2019-04-17  騰輝電子-KY           95.0
# 978  2019-04-18  騰輝電子-KY           88.0
# 978  2019-04-19  騰輝電子-KY           93.2
# 978  2019-04-22  騰輝電子-KY           94.0
# 978  2019-04-23  騰輝電子-KY           94.9
# ...         ...      ...            ...
# 1002 2019-12-25  騰輝電子-KY           94.4
# 1002 2019-12-26  騰輝電子-KY           97.2
# 1002 2019-12-27  騰輝電子-KY           96.1
# 1001 2019-12-30  騰輝電子-KY           95.3
# 1001 2019-12-31  騰輝電子-KY           95.1
#
# [178 rows x 3 columns]
# 高力
#            date name  closing_price
# 1018 2019-01-02   高力          36.75
# 1018 2019-01-03   高力          36.45
# 1018 2019-01-04   高力          35.80
# 1018 2019-01-07   高力          36.25
# 1019 2019-01-08   高力          36.10
# ...         ...  ...            ...
# 1061 2019-12-25   高力          54.50
# 1061 2019-12-26   高力          52.40
# 1061 2019-12-27   高力          53.70
# 1060 2019-12-30   高力          52.40
# 1060 2019-12-31   高力          52.30
#
# [242 rows x 3 columns]
# 高林
#           date name  closing_price
# 625 2019-01-02   高林           9.47
# 625 2019-01-03   高林           9.46
# 625 2019-01-04   高林           9.50
# 625 2019-01-07   高林           9.69
# 626 2019-01-08   高林          10.45
# ..         ...  ...            ...
# 652 2019-12-25   高林          11.55
# 652 2019-12-26   高林          11.50
# 652 2019-12-27   高林          11.40
# 651 2019-12-30   高林          11.50
# 651 2019-12-31   高林          11.50
#
# [242 rows x 3 columns]
# 高林股
#           date name  closing_price
# 244 2019-01-02  高林股          16.15
# 244 2019-01-03  高林股          15.90
# 244 2019-01-04  高林股          15.80
# 244 2019-01-07  高林股          15.90
# 244 2019-01-08  高林股          15.85
# ..         ...  ...            ...
# 266 2019-12-25  高林股          15.20
# 266 2019-12-26  高林股          15.15
# 266 2019-12-27  高林股          15.25
# 265 2019-12-30  高林股          15.15
# 265 2019-12-31  高林股          15.20
#
# [242 rows x 3 columns]
# 高興昌
#           date name  closing_price
# 331 2019-01-02  高興昌          12.35
# 331 2019-01-03  高興昌          12.35
# 331 2019-01-04  高興昌          12.35
# 331 2019-01-07  高興昌          12.35
# 331 2019-01-08  高興昌          12.35
# ..         ...  ...            ...
# 353 2019-12-24  高興昌          12.35
# 353 2019-12-25  高興昌          12.35
# 353 2019-12-26  高興昌          12.35
# 353 2019-12-27  高興昌          12.50
# 352 2019-12-30  高興昌          12.35
#
# [231 rows x 3 columns]
# 高雄銀
#           date name  closing_price
# 590 2019-01-02  高雄銀           9.11
# 590 2019-01-03  高雄銀           9.12
# 590 2019-01-04  高雄銀           9.10
# 590 2019-01-07  高雄銀           9.27
# 590 2019-01-08  高雄銀           9.25
# ..         ...  ...            ...
# 613 2019-12-25  高雄銀           9.81
# 613 2019-12-26  高雄銀           9.80
# 613 2019-12-27  高雄銀           9.81
# 612 2019-12-30  高雄銀           9.80
# 612 2019-12-31  高雄銀           9.78
#
# [242 rows x 3 columns]
# 鮮活果汁-KY
#           date     name  closing_price
# 148 2019-01-02  鮮活果汁-KY          140.5
# 148 2019-01-03  鮮活果汁-KY          138.5
# 148 2019-01-04  鮮活果汁-KY          138.5
# 148 2019-01-07  鮮活果汁-KY          152.0
# 148 2019-01-08  鮮活果汁-KY          151.0
# ..         ...      ...            ...
# 171 2019-12-25  鮮活果汁-KY          219.0
# 171 2019-12-26  鮮活果汁-KY          220.0
# 171 2019-12-27  鮮活果汁-KY          226.0
# 170 2019-12-30  鮮活果汁-KY          221.0
# 170 2019-12-31  鮮活果汁-KY          220.5
#
# [242 rows x 3 columns]
# 鳳凰
#           date name  closing_price
# 864 2019-01-02   鳳凰          35.25
# 864 2019-01-03   鳳凰          35.25
# 864 2019-01-04   鳳凰          34.80
# 864 2019-01-07   鳳凰          34.80
# 865 2019-01-08   鳳凰          34.80
# ..         ...  ...            ...
# 897 2019-12-25   鳳凰          40.65
# 897 2019-12-26   鳳凰          40.85
# 897 2019-12-27   鳳凰          40.70
# 896 2019-12-30   鳳凰          40.60
# 896 2019-12-31   鳳凰          40.40
#
# [242 rows x 3 columns]
# 鴻名
#           date name  closing_price
# 651 2019-01-02   鴻名          14.40
# 651 2019-01-03   鴻名          14.45
# 651 2019-01-04   鴻名          14.30
# 651 2019-01-07   鴻名          14.40
# 652 2019-01-08   鴻名          14.40
# ..         ...  ...            ...
# 678 2019-12-25   鴻名          15.70
# 678 2019-12-26   鴻名          15.70
# 678 2019-12-27   鴻名          15.85
# 677 2019-12-30   鴻名          15.85
# 677 2019-12-31   鴻名          15.75
#
# [242 rows x 3 columns]
# 鴻海
#           date name  closing_price
# 387 2019-01-02   鴻海           70.1
# 387 2019-01-03   鴻海           68.9
# 387 2019-01-04   鴻海           67.6
# 387 2019-01-07   鴻海           69.3
# 387 2019-01-08   鴻海           68.6
# ..         ...  ...            ...
# 411 2019-12-25   鴻海           91.0
# 411 2019-12-26   鴻海           90.8
# 411 2019-12-27   鴻海           91.5
# 410 2019-12-30   鴻海           90.9
# 410 2019-12-31   鴻海           90.8
#
# [242 rows x 3 columns]
# 鴻準
#           date name  closing_price
# 409 2019-01-02   鴻準           60.1
# 409 2019-01-03   鴻準           60.0
# 409 2019-01-04   鴻準           58.9
# 409 2019-01-07   鴻準           58.9
# 409 2019-01-08   鴻準           58.7
# ..         ...  ...            ...
# 433 2019-12-25   鴻準           67.5
# 433 2019-12-26   鴻準           67.0
# 433 2019-12-27   鴻準           67.0
# 432 2019-12-30   鴻準           66.6
# 432 2019-12-31   鴻準           66.2
#
# [242 rows x 3 columns]
# 麗嬰房
#           date name  closing_price
# 628 2019-01-02  麗嬰房           9.95
# 628 2019-01-03  麗嬰房           9.92
# 628 2019-01-04  麗嬰房           9.90
# 628 2019-01-07  麗嬰房           9.83
# 629 2019-01-08  麗嬰房           9.81
# ..         ...  ...            ...
# 655 2019-12-25  麗嬰房           7.52
# 655 2019-12-26  麗嬰房           7.54
# 655 2019-12-27  麗嬰房           7.53
# 654 2019-12-30  麗嬰房           7.54
# 654 2019-12-31  麗嬰房           7.58
#
# [242 rows x 3 columns]
# 麗正
#           date name  closing_price
# 379 2019-01-02   麗正           7.44
# 379 2019-01-03   麗正           7.45
# 379 2019-01-04   麗正           7.39
# 379 2019-01-07   麗正           8.12
# 379 2019-01-08   麗正           8.63
# ..         ...  ...            ...
# 403 2019-12-25   麗正           7.88
# 403 2019-12-26   麗正           8.66
# 403 2019-12-27   麗正           8.59
# 402 2019-12-30   麗正           8.24
# 402 2019-12-31   麗正           8.21
#
# [242 rows x 3 columns]
# 麗清
#           date name  closing_price
# 709 2019-01-02   麗清          34.45
# 709 2019-01-03   麗清          34.65
# 709 2019-01-04   麗清          33.50
# 709 2019-01-07   麗清          34.40
# 710 2019-01-08   麗清          34.40
# ..         ...  ...            ...
# 736 2019-12-25   麗清          30.10
# 736 2019-12-26   麗清          30.80
# 736 2019-12-27   麗清          30.65
# 735 2019-12-30   麗清          30.15
# 735 2019-12-31   麗清          30.35
#
# [242 rows x 3 columns]
# 麗臺
#           date name  closing_price
# 491 2019-01-02   麗臺          10.70
# 491 2019-01-03   麗臺          10.35
# 491 2019-01-04   麗臺          10.20
# 491 2019-01-07   麗臺          10.35
# 491 2019-01-08   麗臺          10.35
# ..         ...  ...            ...
# 515 2019-12-25   麗臺          11.20
# 515 2019-12-26   麗臺          11.20
# 515 2019-12-27   麗臺          11.15
# 514 2019-12-30   麗臺          11.10
# 514 2019-12-31   麗臺          11.10
#
# [242 rows x 3 columns]
# 麗豐-KY
#           date   name  closing_price
# 775 2019-01-02  麗豐-KY          253.0
# 775 2019-01-03  麗豐-KY          252.5
# 775 2019-01-04  麗豐-KY          259.5
# 775 2019-01-07  麗豐-KY          260.5
# 776 2019-01-08  麗豐-KY          257.0
# ..         ...    ...            ...
# 802 2019-12-25  麗豐-KY          239.5
# 802 2019-12-26  麗豐-KY          239.0
# 802 2019-12-27  麗豐-KY          237.0
# 801 2019-12-30  麗豐-KY          239.5
# 801 2019-12-31  麗豐-KY          238.0
#
# [242 rows x 3 columns]
# 黑松
#           date name  closing_price
# 145 2019-01-02   黑松          29.65
# 145 2019-01-03   黑松          29.75
# 145 2019-01-04   黑松          29.90
# 145 2019-01-07   黑松          30.00
# 145 2019-01-08   黑松          29.85
# ..         ...  ...            ...
# 168 2019-12-25   黑松          32.30
# 168 2019-12-26   黑松          32.65
# 168 2019-12-27   黑松          32.55
# 167 2019-12-30   黑松          32.50
# 167 2019-12-31   黑松          32.55
#
# [242 rows x 3 columns]
# 鼎元
#           date name  closing_price
# 460 2019-01-02   鼎元          16.80
# 460 2019-01-03   鼎元          16.70
# 460 2019-01-04   鼎元          16.95
# 460 2019-01-07   鼎元          17.20
# 460 2019-01-08   鼎元          17.10
# ..         ...  ...            ...
# 484 2019-12-25   鼎元          14.70
# 484 2019-12-26   鼎元          14.90
# 484 2019-12-27   鼎元          15.20
# 483 2019-12-30   鼎元          15.25
# 483 2019-12-31   鼎元          15.55
#
# [242 rows x 3 columns]
# 鼎固-KY
#           date   name  closing_price
# 632 2019-01-02  鼎固-KY          18.85
# 632 2019-01-03  鼎固-KY          18.60
# 632 2019-01-04  鼎固-KY          18.65
# 632 2019-01-07  鼎固-KY          19.55
# 633 2019-01-08  鼎固-KY          18.50
# ..         ...    ...            ...
# 659 2019-12-25  鼎固-KY          27.15
# 659 2019-12-26  鼎固-KY          27.15
# 659 2019-12-27  鼎固-KY          27.20
# 658 2019-12-30  鼎固-KY          27.25
# 658 2019-12-31  鼎固-KY          27.05
#
# [242 rows x 3 columns]
# 鼎炫-KY
#            date   name  closing_price
# 1015 2019-01-02  鼎炫-KY           89.6
# 1015 2019-01-03  鼎炫-KY           88.2
# 1015 2019-01-04  鼎炫-KY           84.9
# 1015 2019-01-07  鼎炫-KY           90.3
# 1016 2019-01-08  鼎炫-KY           89.2
# ...         ...    ...            ...
# 1058 2019-12-25  鼎炫-KY          104.0
# 1058 2019-12-26  鼎炫-KY          104.0
# 1058 2019-12-27  鼎炫-KY          109.5
# 1057 2019-12-30  鼎炫-KY          108.5
# 1057 2019-12-31  鼎炫-KY          108.0
#
# [242 rows x 3 columns]
# 龍燈-KY
#           date   name  closing_price
# 776 2019-01-02  龍燈-KY          18.70
# 776 2019-01-03  龍燈-KY          18.80
# 776 2019-01-04  龍燈-KY          18.30
# 776 2019-01-07  龍燈-KY          18.50
# 777 2019-01-08  龍燈-KY          18.85
# ..         ...    ...            ...
# 803 2019-12-25  龍燈-KY          14.40
# 803 2019-12-26  龍燈-KY          14.60
# 803 2019-12-27  龍燈-KY          14.55
# 802 2019-12-30  龍燈-KY          14.50
# 802 2019-12-31  龍燈-KY          14.75
#
# [242 rows x 3 columns]
# 龍邦
#           date name  closing_price
# 525 2019-01-02   龍邦          17.55
# 525 2019-01-03   龍邦          17.40
# 525 2019-01-04   龍邦          17.30
# 525 2019-01-07   龍邦          17.75
# 525 2019-01-08   龍邦          17.75
# ..         ...  ...            ...
# 548 2019-12-25   龍邦          15.65
# 548 2019-12-26   龍邦          15.70
# 548 2019-12-27   龍邦          15.65
# 547 2019-12-30   龍邦          15.55
# 547 2019-12-31   龍邦          15.40
#
# [234 rows x 3 columns]

# %% [markdown]
# ### 以組進行計算總和

# %%
data_group.count().head()
# Out:
#           date  closing_price
# name
# BP上證50     230            230
# FH富時不動產    242            242
# FH富時高息低波   221            221
# FH彭博新興債    242            242
# FH彭博高收益債   242            242

# %% [markdown]
# ### 以組進行計算平均

# %%
data_group.sum().head()
# Out:
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\1340209142.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_group.sum().head()
#           closing_price
# name
# BP上證50         23863.65
# FH富時不動產         4410.58
# FH富時高息低波       10785.16
# FH彭博新興債         5179.00
# FH彭博高收益債        5007.56

# %%
data_group.mean().head()
# Out:
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\298960885.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_group.mean()
#           closing_price
# name
# BP上證50       103.755000
# FH富時不動產       18.225537
# FH富時高息低波      48.801629
# FH彭博新興債       21.400826
# FH彭博高收益債      20.692397
# ...                 ...
# 鼎元            16.244421
# 鼎固-KY         23.478926
# 鼎炫-KY        108.563636
# 龍燈-KY         17.568388
# 龍邦            16.238034
#
# [1127 rows x 1 columns]

# %%
data_group.get_group('中信金').mean()
# Out:
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\303006644.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data_group.get_group('中信金').mean()
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\303006644.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_group.get_group('中信金').mean()
# closing_price    20.958264
# dtype: float64

# %%
data[data['name']=='國泰金'].mean()
# Out:
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\425421573.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data[data['name']=='國泰金'].mean()
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\425421573.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data[data['name']=='國泰金'].mean()
# closing_price    42.465083
# dtype: float64

# %% [markdown]
# ### 以組進行describe()

# %%
data_group.describe().head()
# Out:
#          closing_price                                                  \
#                  count        mean       std    min       25%      50%
# name
# BP上證50           230.0  103.755000  6.146488  83.65  102.2625  105.425
# FH富時不動產          242.0   18.225537  0.445537  17.05   17.9000   18.305
# FH富時高息低波         221.0   48.801629  0.998314  45.50   48.1200   48.800
# FH彭博新興債          242.0   21.400826  1.221931  18.84   20.4100   21.700
# FH彭博高收益債         242.0   20.692397  0.304929  19.63   20.5300   20.735
#
#
#                75%     max
# name
# BP上證50    107.7875  112.80
# FH富時不動產    18.5700   19.25
# FH富時高息低波   49.5100   50.70
# FH彭博新興債    22.2800   23.71
# FH彭博高收益債   20.9100   21.25

# %% [markdown]
# ## corr 相關係數
#
# ### 0.1 <= |ans| <0.3 相關度:低
# ### 0.3 <= |ans| <0.5 相關度:中
# ### 0.5 <= |ans| <1.0 相關度:高

# %%
#提出中信金與國泰金資料

data_CH = data[data['name']=='中信金'].reset_index(drop=True)
data_KT = data[data['name']=='國泰金'].reset_index(drop=True)
# Out:
#           date name  closing_price
# 0   2019-01-02  中信金          19.90
# 1   2019-01-03  中信金          20.00
# 2   2019-01-04  中信金          19.80
# 3   2019-01-07  中信金          20.10
# 4   2019-01-08  中信金          19.95
# ..         ...  ...            ...
# 237 2019-12-25  中信金          22.45
# 238 2019-12-26  中信金          22.45
# 239 2019-12-27  中信金          22.50
# 240 2019-12-30  中信金          22.50
# 241 2019-12-31  中信金          22.40
#
# [242 rows x 3 columns]

# %%
data_CH.head()
# Out:
#         date name  closing_price
# 0 2019-01-02  中信金          19.90
# 1 2019-01-03  中信金          20.00
# 2 2019-01-04  中信金          19.80
# 3 2019-01-07  中信金          20.10
# 4 2019-01-08  中信金          19.95

# %%
data_CH.count()
# Out:
# date             242
# name             242
# closing_price    242
# dtype: int64

# %%
data_KT.head()
# Out:
#         date name  closing_price
# 0 2019-01-02  國泰金          45.90
# 1 2019-01-03  國泰金          45.15
# 2 2019-01-04  國泰金          44.55
# 3 2019-01-07  國泰金          45.20
# 4 2019-01-08  國泰金          45.15

# %%
data_KT.count()
# Out:
# date             242
# name             242
# closing_price    242
# dtype: int64

# %%
data_CH['closing_price'].corr(data_KT['closing_price']) ## 計算兩支股票的相關係數
# Out:
# -0.040024190759576285

# %% [markdown]
# ### 計算所有公司與中信金的相關度

# %%
#需15秒

#製作一個新的dataframe去接資料
data_CH_corr_company = pd.DataFrame()
#製作所有公司的list，方法 : 將data的name這個columns刪除重複項
companies = data['name'].drop_duplicates()
data_CH_corr_company['company'] = companies
data_CH_corr_company['corr'] = 0

#利用apply遍歷所有公司
def get_corr(x):
    data_company = data[data['name']==x].reset_index(drop=True)
    return data_CH['closing_price'].corr(data_company['closing_price'])                                    
data_CH_corr_company['corr'] = data_CH_corr_company['company'].apply(get_corr)

# %%
#排序過後的相關度dataframe
data_CH_corr_company.sort_values('corr',ascending = False)
# Out:
#       company      corr
# 617       中信金  1.000000
# 864        鳳凰  0.860940
# 486        敦吉  0.847900
# 597       中再保  0.844067
# 325       永豐餘  0.834481
# ..        ...       ...
# 634     新光金甲特 -0.761325
# 78   兆豐藍籌30反1 -0.791579
# 48     國泰日本反1 -0.801632
# 29     富邦日本反1 -0.809789
# 128  國泰US短期公債 -0.868759
#
# [1127 rows x 2 columns]

# %%
#絕對值並排續後的相關度dataframe
data_CH_corr_company['corr'] = data_CH_corr_company['corr'].abs()
data_CH_corr_company.sort_values('corr',ascending = False)
# Out:
#       company      corr
# 617       中信金  1.000000
# 128  國泰US短期公債  0.868759
# 864        鳳凰  0.860940
# 486        敦吉  0.847900
# 597       中再保  0.844067
# ..        ...       ...
# 96    富邦美國特別股  0.004113
# 300        毛寶  0.002086
# 782     佐登-KY  0.001324
# 898        巨路  0.001162
# 396        友訊  0.000597
#
# [1127 rows x 2 columns]

# %% [markdown]
# # matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
#將中信金與國泰金merge起來，請參考lab5
data_CH_KT = pd.merge(data_CH[['date','closing_price']],data_KT[['date','closing_price']],on='date',suffixes=('_CH', '_KT')).set_index('date')

# %%
data_CH_KT
# Out:
#             closing_price_CH  closing_price_KT
# date
# 2019-01-02             19.90             45.90
# 2019-01-03             20.00             45.15
# 2019-01-04             19.80             44.55
# 2019-01-07             20.10             45.20
# 2019-01-08             19.95             45.15
# ...                      ...               ...
# 2019-12-25             22.45             42.60
# 2019-12-26             22.45             42.65
# 2019-12-27             22.50             42.70
# 2019-12-30             22.50             42.70
# 2019-12-31             22.40             42.55
#
# [242 rows x 2 columns]

# %% [markdown]
# ## plt.plot

# %%
plt.plot(data_CH_KT['closing_price_CH'],label='CH')
plt.plot(data_CH_KT['closing_price_KT'],label='KT')
plt.show()

# %% [markdown]
# ### 設定坐標軸與標題名稱
#
# ### xlabel、ylabe、title

# %%
plt.plot(data_CH_KT['closing_price_CH'],label='CH')
plt.plot(data_CH_KT['closing_price_KT'],label='KT')
#x坐標軸
plt.xlabel("date")
#y坐標軸
plt.ylabel("closing_price")
#標題
plt.title("Test")
plt.show()

# %% [markdown]
# ### 設定大小
#
# ### figure(figsize(x,y))

# %%
#設定大小
plt.figure(figsize=(10,4))
plt.plot(data_CH_KT['closing_price_CH'],label='CH')
plt.plot(data_CH_KT['closing_price_KT'],label='KT')
plt.xlabel("date")
plt.ylabel("closing_price")
plt.title("Test")
plt.show()

# %% [markdown]
# ### 設定坐標軸刻度
#
# ### xticks、yticks

# %%
plt.figure(figsize=(10,4))
plt.plot(data_CH_KT['closing_price_CH'],label='CH')
plt.plot(data_CH_KT['closing_price_KT'],label='KT')
#設定刻度
plt.yticks(np.arange(0, 100, 20))
plt.xlabel("date")
plt.ylabel("closing_price")
plt.title("Test")
plt.show()

# %% [markdown]
# ### 設定圖例
#
# ### legend()

# %%
plt.figure(figsize=(10,4))
plt.plot(data_CH_KT['closing_price_CH'],label='CH')
plt.plot(data_CH_KT['closing_price_KT'],label='KT')
plt.legend(loc='best')
plt.yticks(np.arange(0, 100, 20))
plt.xlabel("date")
plt.ylabel("closing_price")
plt.title("Test")
plt.show()

# %% [markdown]
# ### 設定顏色
#
# ### color

# %%
plt.figure(figsize=(10,4))
plt.plot(data_CH_KT['closing_price_CH'],label='CH',color='gold')
plt.plot(data_CH_KT['closing_price_KT'],label='MTK',color='forestgreen')
plt.legend(loc='best')
plt.yticks(np.arange(0, 100, 20))
plt.xlabel("date")
plt.ylabel("closing_price")
plt.title("Test")
plt.show()

# %% [markdown]
# ## 作業三 (due 5/2/2023)
#
#
# ## 1. 請計算　台積電、聯發科和聯電　2022年的股價平均值?
#
# ## 2. 請分析2022/1/1-2022/12/31期間與台積電絕對值相關度排行第10名的股票是哪一支股票？劃出這兩支股票的股價圖表 (圖表必須包含圖例、座標軸名稱、標題、大小為(7,7))

# %%
#參考lab5
data = pd.read_csv('./data_science_data.csv',index_col=0)
#提取資料
data = data[['date','證券名稱','收盤價']]
#更改名字
data = data.rename(columns = {'證券名稱':'name'})
data = data.rename(columns = {'收盤價':'closing_price'})
#清理資料
data['closing_price'] = data['closing_price'].replace({'\$':'', ',':'', '--':np.nan}, regex=True)
data = data.dropna()
#更改資料型態
data['closing_price'] = data['closing_price'].astype('float64')
data['date'] = pd.to_datetime(data['date'])
#分組
data_group = data.groupby('name')
data_TSMC = data_group.get_group('台積電')
data_MTK = data_group.get_group('聯發科')
data_UMC = data_group.get_group('聯電')
#第一題印出
print('台積電股價')
display(data_TSMC.mean())
print('聯發科股價')
display(data_MTK.mean())
print('聯電股價')
display(data_UMC.mean())
# Out:
# 台積電股價
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:21: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   display(data_TSMC.mean())
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:21: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   display(data_TSMC.mean())
# closing_price    261.733471
# dtype: float64
# 聯發科股價
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:23: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   display(data_MTK.mean())
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:23: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   display(data_MTK.mean())
# closing_price    329.772727
# dtype: float64
# 聯電股價
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:25: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   display(data_UMC.mean())
# C:\Users\bob10\AppData\Local\Temp\ipykernel_2664\400812577.py:25: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   display(data_UMC.mean())
# closing_price    13.316942
# dtype: float64
